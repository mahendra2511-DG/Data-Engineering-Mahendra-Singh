# %% [markdown]
# ## Data Overview
#
# * Data is automatically generated for you via the [Datagen](../datagen/README.html) utility.
# * Data is loaded into a PostgreSQL database, which will act as the source system for this course.
# * Shown below is an overview of the source tables that we will use throughout this course.
#
# ```
# customer
#   ├── customer_address  (1:N)
#   ├── device            (1:N)
#   ├── session           (1:N)
#   │     └── ad_impression  (1:N)
#   │           └── ad_click      (1:N)
#   │                 └── ad_conversion  (1:N)
#   └── order             (1:N)
#         ├── order_line  (1:N)
#         └── payment     (1:1)
#
#
# product_category        (self-referencing)
#   └── product
#         └── product_variant
#               ├── product_attribute  (1:N)
#               └── inventory          (1:N)
#
# advertiser
#   └── campaign
#         └── ad_group
#               ├── ad_creative       (1:N)
#               └── ad_group_keyword  (M:N)
#
# ```

# %% [markdown]
# ## JupyterLab Overview
#
# * This course contains all the information, code and exercises in Jupyter notebooks
# * Please follow along by running the code in the Jupyter **notebooks folder**. which has one notebook per section

# %%
# %%sql
# select 'run postgres query', 1 as id, * from customer limit 2

# %%
a = 10
a * 10

# %%
# %%bash
# ls -l
